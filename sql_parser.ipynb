# %%
import sqlite3

# %%
DB_PATH = 'scripts\\articles.db'

# %%
conn = sqlite3.connect(DB_PATH)
cursor = conn.cursor()

# %%
SHOW_TABLES = "SELECT name FROM sqlite_master WHERE type='table';"
SELECT_ALL = "SELECT * FROM stock_data"
SELECT_ALL_preds = "SELECT * FROM preds"

# %%
cursor.execute(SELECT_ALL_preds).fetchall()
# Out:
# [('2024-11-21',
#   'TSLA',
#   'Automotive',
#   339.6400146484375,
#   346.054626785437,
#   335.02880859375,
#   339.0770980834962),
#  ('2024-11-22',
#   'TSLA',
#   'Automotive',
#   352.55999755859375,
#   333.05819451989754,
#   327.9515075683594,
#   320.96899871826156),
#  ('2024-11-25',
#   'TSLA',
#   'Automotive',
#   338.5899963378906,
#   352.0287277399212,
#   325.1226806640625,
#   317.9121990966795),
#  ('2024-11-26',
#   'TSLA',
#   'Automotive',
#   338.2300109863281,
#   343.94656639812996,
#   325.1874694824219,
#   317.71639892578105),
#  ('2024-11-27',
#   'TSLA',
#   'Automotive',
#   332.8900146484375,
#   335.4740370108631,
#   325.08819580078125,
#   317.82569885253895),
#  ('2024-11-29',
#   'TSLA',
#   'Automotive',
#   345.1600036621094,
#   337.382962320804,
#   325.1139221191406,
#   317.6335986328123),
#  ('2024-12-02',
#   'TSLA',
#   'Automotive',
#   357.0899963378906,
#   342.23811605115844,
#   324.9617004394531,
#   317.8632989501951),
# ...

# %%
conn.close()
